# %%
import pandas as pd
csvdata = pd.read_csv("COVID19_line_list_data.csv")
csvdata
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 0        1              NaN      1/20/2020         NaN
# 1        2              NaN      1/20/2020         NaN
# 2        3              NaN      1/21/2020         NaN
# 3        4              NaN      1/21/2020         NaN
# 4        5              NaN      1/21/2020         NaN
# 5        6              NaN      1/21/2020         NaN
# 6        7              NaN      1/21/2020         NaN
# 7        8              NaN      1/21/2020         NaN
# 8        9              NaN      1/21/2020         NaN
# 9       10              NaN      1/21/2020         NaN
# 10      11              NaN      1/21/2020         NaN
# 11      12              NaN      1/21/2020         NaN
# 12      13              NaN      1/21/2020         NaN
# 13      14              NaN      1/21/2020         NaN
# 14      15              NaN      1/22/2020         NaN
# 15      16              NaN      1/22/2020         NaN
# ...

# %%
csvdata.groupby(by='country')['age'].mean()
# Out:
# country
# Afghanistan    35.000000
# Algeria              NaN
# Australia      42.000000
# Austria        24.000000
# Bahrain              NaN
# Belgium              NaN
# Cambodia       60.000000
# Canada         42.583333
# China          49.000000
# Croatia              NaN
# Egypt                NaN
# Finland        32.000000
# France         46.611111
# Germany        40.214286
# Hong Kong      56.075269
# India                NaN
# Iran                 NaN
# Israel               NaN
# Italy          35.000000
# Japan          55.462366
# Kuwait               NaN
# Lebanon        45.000000
# Malaysia       41.304348
# Nepal          32.000000
# Phillipines    47.333333
# Russia               NaN
# Singapore      43.516667
# South Korea    47.641304
# Spain          43.809524
# Sri Lanka      40.000000
# Sweden         25.000000
# Switzerland    70.000000
# Taiwan         51.935484
# Thailand       48.166667
# UAE            44.666667
# UK             53.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sea
data = pd.read_csv("cases_add_Taiwan.csv")
data
# Out:
#     Date  Worldwide  Taiwan  Afghanistan  Albania  Algeria  Andorra  \
# 0   1/21          0       1          NaN      NaN      NaN      NaN
# 1   1/22         32       1          NaN      NaN      NaN      NaN
# 2   1/23        266       1          NaN      NaN      NaN      NaN
# 3   1/24        262       3          NaN      NaN      NaN      NaN
# 4   1/25        467       3          NaN      NaN      NaN      NaN
# 5   1/26        691       4          NaN      NaN      NaN      NaN
# 6   1/27        783       5          NaN      NaN      NaN      NaN
# 7   1/28       1792       8          NaN      NaN      NaN      NaN
# 8   1/29       1468       8          NaN      NaN      NaN      NaN
# 9   1/30       1750       9          NaN      NaN      NaN      NaN
# 10  1/31       2006      10          NaN      NaN      NaN      NaN
# 11   2/1       2121      10          NaN      NaN      NaN      NaN
# 12   2/2       2604      10          NaN      NaN      NaN      NaN
# ...

# %%
data[['Worldwide','Date']].plot(kind = 'line',x='Date',y='Worldwide',title = "world case",legend=False)
plt.show()

# %%
G = data['Germany']
D = data['Date']
T = data['Taiwan']
M = data['Malaysia']
plt.plot(D,G,label='Germany')
plt.plot(D,T,label='Taiwan')
plt.plot(D,M,label='Malaysia')
plt.legend()
plt.xlim('3/5','3/15')
# Out:
# (array([44.]), array([53.]))

# %%
class score:
    def __init__(self,n,s):
        self.score1 = s
        self.number = n

n=input('enter your number:')
s=input('enter your score:')
yourscore = score(n,s)
print("your score:"+str(yourscore.score1))
# Out:
# enter your number:12
# enter your score:12
# your score:12
